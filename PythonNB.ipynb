# %% [markdown]
# <a href="https://colab.research.google.com/github/data-analytics-leader-kunjanmehta/analytics-portfolio/blob/main/PythonNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My Analytics Portfolio Project Started")
# Out:
# My Analytics Portfolio Project Started
